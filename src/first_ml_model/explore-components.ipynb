# %%
# !pip install kfp==2.5.0 mlflow==2.15.1 kserve==0.13.1 tenacity
# Out:
# Collecting kfp==2.5.0
#   Downloading kfp-2.5.0.tar.gz (425 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: mlflow==2.15.1 in /opt/conda/lib/python3.11/site-packages (2.15.1)
# Collecting kserve==0.13.1
#   Downloading kserve-0.13.1-py3-none-any.whl.metadata (9.1 kB)
# Requirement already satisfied: tenacity in /opt/conda/lib/python3.11/site-packages (8.5.0)
# Requirement already satisfied: click<9,>=8.0.0 in /opt/conda/lib/python3.11/site-packages (from kfp==2.5.0) (8.2.1)
# Requirement already satisfied: docstring-parser<1,>=0.7.3 in /opt/conda/lib/python3.11/site-packages (from kfp==2.5.0) (0.16)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /opt/conda/lib/python3.11/site-packages (from kfp==2.5.0) (2.25.1)
# Requirement already satisfied: google-auth<3,>=1.6.1 in /opt/conda/lib/python3.11/site-packages (from kfp==2.5.0) (2.40.3)
# Requirement already satisfied: google-cloud-storage<3,>=2.2.1 in /opt/conda/lib/python3.11/site-packages (from kfp==2.5.0) (2.19.0)
# Collecting kfp-pipeline-spec==0.2.2 (from kfp==2.5.0)
#   Downloading kfp_pipeline_spec-0.2.2-py3-none-any.whl.metadata (295 bytes)
# Collecting kfp-server-api<2.1.0,>=2.0.0 (from kfp==2.5.0)
#   Downloading kfp-server-api-2.0.5.tar.gz (63 kB)
#   Preparing metadata (setup.py) ... done
# Collecting kubernetes<27,>=8.0.0 (from kfp==2.5.0)
#   Downloading kubernetes-26.1.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting protobuf<4,>=3.13.0 (from kfp==2.5.0)
#   Downloading protobuf-3.20.3-py2.py3-none-any.whl.metadata (720 bytes)
# Requirement already satisfied: PyYAML<7,>=5.3 in /opt/conda/lib/python3.11/site-packages (from kfp==2.5.0) (6.0.2)
# Requirement already satisfied: requests-toolbelt<1,>=0.8.0 in /opt/conda/lib/python3.11/site-packages (from kfp==2.5.0) (0.10.1)
# Requirement already satisfied: tabulate<1,>=0.8.6 in /opt/conda/lib/python3.11/site-packages (from kfp==2.5.0) (0.9.0)
# Requirement already satisfied: urllib3<2.0.0 in /opt/conda/lib/python3.11/site-packages (from kfp==2.5.0) (1.26.20)
# Requirement already satisfied: mlflow-skinny==2.15.1 in /opt/conda/lib/python3.11/site-packages (from mlflow==2.15.1) (2.15.1)
# Requirement already satisfied: Flask<4 in /opt/conda/lib/python3.11/site-packages (from mlflow==2.15.1) (3.1.1)
# Requirement already satisfied: alembic!=1.10.0,<2 in /opt/conda/lib/python3.11/site-packages (from mlflow==2.15.1) (1.16.2)
# Requirement already satisfied: docker<8,>=4.0.0 in /opt/conda/lib/python3.11/site-packages (from mlflow==2.15.1) (7.1.0)
# Requirement already satisfied: graphene<4 in /opt/conda/lib/python3.11/site-packages (from mlflow==2.15.1) (3.4.3)
# Requirement already satisfied: markdown<4,>=3.3 in /opt/conda/lib/python3.11/site-packages (from mlflow==2.15.1) (3.8)
# Requirement already satisfied: matplotlib<4 in /opt/conda/lib/python3.11/site-packages (from mlflow==2.15.1) (3.10.0)
# Requirement already satisfied: numpy<2 in /opt/conda/lib/python3.11/site-packages (from mlflow==2.15.1) (1.26.4)
# Requirement already satisfied: pandas<3 in /opt/conda/lib/python3.11/site-packages (from mlflow==2.15.1) (2.2.3)
# Requirement already satisfied: pyarrow<16,>=4.0.0 in /opt/conda/lib/python3.11/site-packages (from mlflow==2.15.1) (15.0.2)
# Requirement already satisfied: querystring-parser<2 in /opt/conda/lib/python3.11/site-packages (from mlflow==2.15.1) (1.2.4)
# Requirement already satisfied: scikit-learn<2 in /opt/conda/lib/python3.11/site-packages (from mlflow==2.15.1) (1.6.1)
# Requirement already satisfied: scipy<2 in /opt/conda/lib/python3.11/site-packages (from mlflow==2.15.1) (1.15.1)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /opt/conda/lib/python3.11/site-packages (from mlflow==2.15.1) (2.0.38)
# Requirement already satisfied: Jinja2<4,>=2.11 in /opt/conda/lib/python3.11/site-packages (from mlflow==2.15.1) (3.1.6)
# Requirement already satisfied: gunicorn<23 in /opt/conda/lib/python3.11/site-packages (from mlflow==2.15.1) (22.0.0)
# Collecting cloudevents<2.0.0,>=1.6.2 (from kserve==0.13.1)
#   Downloading cloudevents-1.12.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting fastapi<0.110.0,>=0.109.1 (from kserve==0.13.1)
#   Downloading fastapi-0.109.2-py3-none-any.whl.metadata (25 kB)
# Collecting grpcio<2.0.0,>=1.49.1 (from kserve==0.13.1)
#   Downloading grpcio-1.73.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting httpx<0.27.0,>=0.26.0 (from kserve==0.13.1)
#   Downloading httpx-0.26.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting orjson<4.0.0,>=3.9.15 (from kserve==0.13.1)
#   Downloading orjson-3.10.18-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (41 kB)
# Collecting prometheus-client<0.21.0,>=0.20.0 (from kserve==0.13.1)
#   Downloading prometheus_client-0.20.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting psutil<6.0.0,>=5.9.0 (from kserve==0.13.1)
#   Downloading psutil-5.9.8-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# Requirement already satisfied: pydantic<3,>1.0 in /opt/conda/lib/python3.11/site-packages (from kserve==0.13.1) (2.10.6)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /opt/conda/lib/python3.11/site-packages (from kserve==0.13.1) (2.9.0.post0)
# Collecting ray<2.11.0,>=2.10.0 (from ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1)
#   Downloading ray-2.10.0-cp311-cp311-manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: six<2.0.0,>=1.16.0 in /opt/conda/lib/python3.11/site-packages (from kserve==0.13.1) (1.17.0)
# Collecting timing-asgi<0.4.0,>=0.3.0 (from kserve==0.13.1)
#   Downloading timing_asgi-0.3.1-py3-none-any.whl.metadata (3.7 kB)
# Collecting uvicorn<0.22.0,>=0.21.1 (from uvicorn[standard]<0.22.0,>=0.21.1->kserve==0.13.1)
#   Downloading uvicorn-0.21.1-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: cachetools<6,>=5.0.0 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==2.15.1->mlflow==2.15.1) (5.5.2)
# Requirement already satisfied: cloudpickle<4 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==2.15.1->mlflow==2.15.1) (3.1.1)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==2.15.1->mlflow==2.15.1) (0.57.0)
# Requirement already satisfied: entrypoints<1 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==2.15.1->mlflow==2.15.1) (0.4)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==2.15.1->mlflow==2.15.1) (3.1.44)
# Requirement already satisfied: importlib-metadata!=4.7.0,<8,>=3.7.0 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==2.15.1->mlflow==2.15.1) (7.2.1)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==2.15.1->mlflow==2.15.1) (1.34.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==2.15.1->mlflow==2.15.1) (1.34.1)
# Requirement already satisfied: packaging<25 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==2.15.1->mlflow==2.15.1) (24.2)
# Requirement already satisfied: pytz<2025 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==2.15.1->mlflow==2.15.1) (2024.2)
# Requirement already satisfied: requests<3,>=2.17.3 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==2.15.1->mlflow==2.15.1) (2.32.4)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==2.15.1->mlflow==2.15.1) (0.5.3)
# Requirement already satisfied: Mako in /opt/conda/lib/python3.11/site-packages (from alembic!=1.10.0,<2->mlflow==2.15.1) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /opt/conda/lib/python3.11/site-packages (from alembic!=1.10.0,<2->mlflow==2.15.1) (4.14.0)
# Collecting deprecation<3.0,>=2.0 (from cloudevents<2.0.0,>=1.6.2->kserve==0.13.1)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Collecting starlette<0.37.0,>=0.36.3 (from fastapi<0.110.0,>=0.109.1->kserve==0.13.1)
#   Downloading starlette-0.36.3-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: blinker>=1.9.0 in /opt/conda/lib/python3.11/site-packages (from Flask<4->mlflow==2.15.1) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /opt/conda/lib/python3.11/site-packages (from Flask<4->mlflow==2.15.1) (2.2.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /opt/conda/lib/python3.11/site-packages (from Flask<4->mlflow==2.15.1) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in /opt/conda/lib/python3.11/site-packages (from Flask<4->mlflow==2.15.1) (3.1.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.11/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.15.1->mlflow==2.15.1) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.15.1->mlflow==2.15.1) (5.0.2)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /opt/conda/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->kfp==2.5.0) (1.70.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /opt/conda/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->kfp==2.5.0) (1.26.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.11/site-packages (from google-auth<3,>=1.6.1->kfp==2.5.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.11/site-packages (from google-auth<3,>=1.6.1->kfp==2.5.0) (4.9.1)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /opt/conda/lib/python3.11/site-packages (from google-cloud-storage<3,>=2.2.1->kfp==2.5.0) (2.4.3)
# Requirement already satisfied: google-resumable-media>=2.7.2 in /opt/conda/lib/python3.11/site-packages (from google-cloud-storage<3,>=2.2.1->kfp==2.5.0) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /opt/conda/lib/python3.11/site-packages (from google-cloud-storage<3,>=2.2.1->kfp==2.5.0) (1.7.1)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /opt/conda/lib/python3.11/site-packages (from graphene<4->mlflow==2.15.1) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /opt/conda/lib/python3.11/site-packages (from graphene<4->mlflow==2.15.1) (3.2.0)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.11/site-packages (from httpx<0.27.0,>=0.26.0->kserve==0.13.1) (3.7.1)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.11/site-packages (from httpx<0.27.0,>=0.26.0->kserve==0.13.1) (2025.6.15)
# Collecting httpcore==1.* (from httpx<0.27.0,>=0.26.0->kserve==0.13.1)
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: idna in /opt/conda/lib/python3.11/site-packages (from httpx<0.27.0,>=0.26.0->kserve==0.13.1) (3.10)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.11/site-packages (from httpx<0.27.0,>=0.26.0->kserve==0.13.1) (1.3.1)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<0.27.0,>=0.26.0->kserve==0.13.1)
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.11/site-packages (from importlib-metadata!=4.7.0,<8,>=3.7.0->mlflow-skinny==2.15.1->mlflow==2.15.1) (3.23.0)
# Requirement already satisfied: setuptools>=21.0.0 in /opt/conda/lib/python3.11/site-packages (from kubernetes<27,>=8.0.0->kfp==2.5.0) (80.9.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /opt/conda/lib/python3.11/site-packages (from kubernetes<27,>=8.0.0->kfp==2.5.0) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /opt/conda/lib/python3.11/site-packages (from kubernetes<27,>=8.0.0->kfp==2.5.0) (2.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4->mlflow==2.15.1) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4->mlflow==2.15.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4->mlflow==2.15.1) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4->mlflow==2.15.1) (1.4.7)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4->mlflow==2.15.1) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4->mlflow==2.15.1) (3.2.3)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.55b1 in /opt/conda/lib/python3.11/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.15.1->mlflow==2.15.1) (0.55b1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas<3->mlflow==2.15.1) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from pydantic<3,>1.0->kserve==0.13.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /opt/conda/lib/python3.11/site-packages (from pydantic<3,>1.0->kserve==0.13.1) (2.27.2)
# Collecting filelock (from ray<2.11.0,>=2.10.0->ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1)
#   Downloading filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: jsonschema in /opt/conda/lib/python3.11/site-packages (from ray<2.11.0,>=2.10.0->ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1) (4.24.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /opt/conda/lib/python3.11/site-packages (from ray<2.11.0,>=2.10.0->ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1) (1.1.1)
# Collecting aiosignal (from ray<2.11.0,>=2.10.0->ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting frozenlist (from ray<2.11.0,>=2.10.0->ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1)
#   Downloading frozenlist-1.7.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting aiohttp-cors (from ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1)
#   Downloading aiohttp_cors-0.8.1-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: watchfiles in /opt/conda/lib/python3.11/site-packages (from ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1) (1.1.0)
# Collecting smart-open (from ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1)
#   Downloading smart_open-7.3.0.post1-py3-none-any.whl.metadata (24 kB)
# Collecting colorful (from ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1)
#   Downloading colorful-0.5.7-py2.py3-none-any.whl.metadata (16 kB)
# Collecting opencensus (from ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1)
#   Downloading opencensus-0.11.4-py2.py3-none-any.whl.metadata (12 kB)
# Collecting py-spy>=0.2.0 (from ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1)
#   Downloading py_spy-0.4.0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (16 kB)
# Collecting virtualenv!=20.21.1,>=20.0.24 (from ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1)
#   Downloading virtualenv-20.31.2-py3-none-any.whl.metadata (4.5 kB)
# Collecting aiohttp>=3.7 (from ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1)
#   Downloading aiohttp-3.12.14-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.15.1->mlflow==2.15.1) (3.4.2)
# Requirement already satisfied: pyasn1>=0.1.3 in /opt/conda/lib/python3.11/site-packages (from rsa<5,>=3.1.4->google-auth<3,>=1.6.1->kfp==2.5.0) (0.6.1)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn<2->mlflow==2.15.1) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn<2->mlflow==2.15.1) (3.6.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.11/site-packages (from sqlalchemy<3,>=1.4.0->mlflow==2.15.1) (3.2.3)
# Requirement already satisfied: httptools>=0.5.0 in /opt/conda/lib/python3.11/site-packages (from uvicorn[standard]<0.22.0,>=0.21.1->kserve==0.13.1) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in /opt/conda/lib/python3.11/site-packages (from uvicorn[standard]<0.22.0,>=0.21.1->kserve==0.13.1) (1.1.0)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /opt/conda/lib/python3.11/site-packages (from uvicorn[standard]<0.22.0,>=0.21.1->kserve==0.13.1) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in /opt/conda/lib/python3.11/site-packages (from uvicorn[standard]<0.22.0,>=0.21.1->kserve==0.13.1) (15.0.1)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp>=3.7->ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp>=3.7->ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1) (25.3.0)
# Collecting multidict<7.0,>=4.5 (from aiohttp>=3.7->ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1)
#   Downloading multidict-6.6.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp>=3.7->ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1)
#   Downloading propcache-0.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp>=3.7->ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1)
#   Downloading yarl-1.20.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (73 kB)
# Collecting distlib<1,>=0.3.7 (from virtualenv!=20.21.1,>=20.0.24->ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1)
#   Downloading distlib-0.3.9-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /opt/conda/lib/python3.11/site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1) (4.3.8)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.11/site-packages (from jsonschema->ray<2.11.0,>=2.10.0->ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.11/site-packages (from jsonschema->ray<2.11.0,>=2.10.0->ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from jsonschema->ray<2.11.0,>=2.10.0->ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1) (0.25.1)
# Collecting opencensus-context>=0.1.3 (from opencensus->ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1)
#   Downloading opencensus_context-0.1.3-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.11/site-packages (from requests-oauthlib->kubernetes<27,>=8.0.0->kfp==2.5.0) (3.2.2)
# Collecting wrapt (from smart-open->ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1)
#   Downloading wrapt-1.17.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Downloading kserve-0.13.1-py3-none-any.whl (452 kB)
# Downloading kfp_pipeline_spec-0.2.2-py3-none-any.whl (20 kB)
# Downloading cloudevents-1.12.0-py3-none-any.whl (55 kB)
# Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Downloading fastapi-0.109.2-py3-none-any.whl (92 kB)
# Downloading grpcio-1.73.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 4.6 MB/s eta 0:00:00a 0:00:01m
# Downloading httpx-0.26.0-py3-none-any.whl (75 kB)
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading kubernetes-26.1.0-py2.py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 3.4 MB/s eta 0:00:00a 0:00:01
# Downloading orjson-3.10.18-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (132 kB)
# Downloading prometheus_client-0.20.0-py3-none-any.whl (54 kB)
# Downloading protobuf-3.20.3-py2.py3-none-any.whl (162 kB)
# Downloading psutil-5.9.8-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
# Downloading ray-2.10.0-cp311-cp311-manylinux2014_x86_64.whl (65.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.6/65.6 MB 3.5 MB/s eta 0:00:0000:0100:01
# Downloading starlette-0.36.3-py3-none-any.whl (71 kB)
# Downloading timing_asgi-0.3.1-py3-none-any.whl (5.6 kB)
# Downloading uvicorn-0.21.1-py3-none-any.whl (57 kB)
# Downloading aiohttp-3.12.14-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 3.4 MB/s eta 0:00:00a 0:00:01
# Downloading multidict-6.6.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (246 kB)
# Downloading yarl-1.20.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (348 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading frozenlist-1.7.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (235 kB)
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading propcache-0.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (213 kB)
# Downloading py_spy-0.4.0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 3.5 MB/s eta 0:00:00a 0:00:01
# Downloading virtualenv-20.31.2-py3-none-any.whl (6.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 3.5 MB/s eta 0:00:00a 0:00:01
# Downloading distlib-0.3.9-py2.py3-none-any.whl (468 kB)
# Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Downloading aiohttp_cors-0.8.1-py3-none-any.whl (25 kB)
# Downloading colorful-0.5.7-py2.py3-none-any.whl (201 kB)
# Downloading opencensus-0.11.4-py2.py3-none-any.whl (128 kB)
# Downloading opencensus_context-0.1.3-py2.py3-none-any.whl (5.1 kB)
# Downloading smart_open-7.3.0.post1-py3-none-any.whl (61 kB)
# Downloading wrapt-1.17.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (83 kB)
# Building wheels for collected packages: kfp, kfp-server-api
#   DEPRECATION: Building 'kfp' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'kfp'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for kfp (setup.py) ... one
#   Created wheel for kfp: filename=kfp-2.5.0-py3-none-any.whl size=585478 sha256=aca2c565826f1e346ec8e8354f7d25921d17c112083e8a9e2c5314e4b0821784
#   Stored in directory: /home/jovyan/.cache/pip/wheels/30/fd/ef/f9aece6ff58e0a2ad78027c3c81a68089702e5a47413f3c6a1
#   DEPRECATION: Building 'kfp-server-api' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'kfp-server-api'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for kfp-server-api (setup.py) ... one
#   Created wheel for kfp-server-api: filename=kfp_server_api-2.0.5-py3-none-any.whl size=114814 sha256=cb2cd2ccd889d6902dd22d65c3dcfa225ebfe93403df4e9bfd6b08c1010c9e0c
#   Stored in directory: /home/jovyan/.cache/pip/wheels/8e/d3/57/08c51747a178cf93f1ae3d2cbb3115f0f3bd6d36c54ce1d9ba
# Successfully built kfp kfp-server-api
# Installing collected packages: py-spy, opencensus-context, distlib, colorful, wrapt, timing-asgi, psutil, protobuf, propcache, prometheus-client, orjson, multidict, h11, grpcio, frozenlist, filelock, deprecation, aiohappyeyeballs, yarl, virtualenv, uvicorn, starlette, smart-open, kfp-server-api, kfp-pipeline-spec, httpcore, cloudevents, aiosignal, kubernetes, httpx, fastapi, aiohttp, ray, opencensus, aiohttp-cors, kserve, kfp
#   Attempting uninstall: psutil━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/37 [distlib]
#     Found existing installation: psutil 7.0.0━━━━━━━━━━━━━━━━━  2/37 [distlib]
#     Uninstalling psutil-7.0.0:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/37 [distlib]
#       Successfully uninstalled psutil-7.0.0━━━━━━━━━━━━━━━━━━━  2/37 [distlib]
#   Attempting uninstall: protobufm━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  6/37 [psutil]
#     Found existing installation: protobuf 6.30.2━━━━━━━━━━━━━━  6/37 [psutil]
#     Uninstalling protobuf-6.30.2:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  6/37 [psutil]
#       Successfully uninstalled protobuf-6.30.2━━━━━━━━━━━━━━━━  6/37 [psutil]
#   Attempting uninstall: prometheus-client━━━━━━━━━━━━━━━━━━━━━━━━━  7/37 [protobuf]
#     Found existing installation: prometheus_client 0.22.1━━━━━  7/37 [protobuf]
#     Uninstalling prometheus_client-0.22.1:━━━━━━━━━━━━━━━━━━━━  7/37 [protobuf]
#       Successfully uninstalled prometheus_client-0.22.1━━━━━━━  7/37 [protobuf]
#   Attempting uninstall: h1190m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  7/37 [protobuf]
#     Found existing installation: h11 0.12.0━━━━━━━━━━━━━━━━━━━  7/37 [protobuf]
#     Uninstalling h11-0.12.0:0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  7/37 [protobuf]
#       Successfully uninstalled h11-0.12.0━━━━━━━━━━━━━━━━━━━━━  7/37 [protobuf]
#   Attempting uninstall: uvicornm╸━━━━━━━━━━━━━━━━━━━ 19/37 [virtualenv]
#     Found existing installation: uvicorn 0.34.0━━━━━━━━━━━━━━━ 19/37 [virtualenv]
#     Uninstalling uvicorn-0.34.0:m╸━━━━━━━━━━━━━━━━━━━ 19/37 [virtualenv]
#       Successfully uninstalled uvicorn-0.34.0━━━━━━━━━━━━━━━━━ 19/37 [virtualenv]
#   Attempting uninstall: starlette╸━━━━━━━━━━━━━━━━━━━ 19/37 [virtualenv]
#     Found existing installation: starlette 0.46.2━━━━━━━━━━━━━ 19/37 [virtualenv]
#     Uninstalling starlette-0.46.2:━━━━━━━━━━━━━━━━━━━ 19/37 [virtualenv]
#       Successfully uninstalled starlette-0.46.2━━━━━━━━━━━━━━━ 19/37 [virtualenv]
#   Attempting uninstall: kfp-server-api1m╸━━━━━━━━━━━━━━━━ 22/37 [smart-open]
#     Found existing installation: kfp-server-api 2.3.0━━━━━━━━━ 22/37 [smart-open]
#     Uninstalling kfp-server-api-2.3.0:━━━━━━━━━━━━━━━━ 22/37 [smart-open]
#       Successfully uninstalled kfp-server-api-2.3.0━━━━━━━━━━━ 22/37 [smart-open]
#   Attempting uninstall: kfp-pipeline-spec━━━━━━━━━━━━━━━━ 22/37 [smart-open]
#     Found existing installation: kfp-pipeline-spec 0.6.0━━━━━━ 22/37 [smart-open]
#     Uninstalling kfp-pipeline-spec-0.6.0:━━━━━━━━━━━━━━━━ 22/37 [smart-open]
#       Successfully uninstalled kfp-pipeline-spec-0.6.0━━━━━━━━ 22/37 [smart-open]
#   Attempting uninstall: httpcore╸━━━━━━━━━━━━━━━━ 22/37 [smart-open]
#     Found existing installation: httpcore 0.15.0━━━━━━━━━━━━━━ 22/37 [smart-open]
#     Uninstalling httpcore-0.15.0:91m╸━━━━━━━━━━━━━━━━ 22/37 [smart-open]
#       Successfully uninstalled httpcore-0.15.0━━━━━━━━━━━━━━━━ 22/37 [smart-open]
#   Attempting uninstall: kubernetes━╺━━━━━━━━━━━━ 25/37 [httpcore]
#     Found existing installation: kubernetes 30.1.0━━━━━━━━━━━━ 25/37 [httpcore]
#     Uninstalling kubernetes-30.1.0:╺━━━━━━━━━━━━ 25/37 [httpcore]
#       Successfully uninstalled kubernetes-30.1.0━━━━━━━━━ 28/37 [kubernetes]
#   Attempting uninstall: httpx━━━━━━━━━╺━━━━━━━━━ 28/37 [kubernetes]
#     Found existing installation: httpx 0.23.090m╺━━━━━━━━ 29/37 [httpx]]
#     Uninstalling httpx-0.23.0:━━━━━╺━━━━━━━━ 29/37 [httpx]
#       Successfully uninstalled httpx-0.23.0m╺━━━━━━━━ 29/37 [httpx]
#   Attempting uninstall: fastapi━━━━╺━━━━━━━━ 29/37 [httpx]
#     Found existing installation: fastapi 0.115.12━━━━━━━━ 29/37 [httpx]
#     Uninstalling fastapi-0.115.12:━╺━━━━━━━━ 29/37 [httpx]
#       Successfully uninstalled fastapi-0.115.120m━━━━━━━━ 29/37 [httpx]
#   Attempting uninstall: kfp━━━━━━━━━━━━━━━━━━╸━━ 35/37 [kserve]]
#     Found existing installation: kfp 2.11.00m╸━━ 35/37 [kserve]
#     Uninstalling kfp-2.11.0:━━━━━━━━━━━━━╸━━ 35/37 [kserve]
#       Successfully uninstalled kfp-2.11.0━━━━━╸━ 36/37 [kfp]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37/37 [kfp]32m36/37 [kfp]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# feast 0.49.0 requires protobuf>=4.24.0, but you have protobuf 3.20.3 which is incompatible.
# feast 0.49.0 requires uvicorn[standard]==0.34.0, but you have uvicorn 0.21.1 which is incompatible.
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.12.14 aiohttp-cors-0.8.1 aiosignal-1.4.0 cloudevents-1.12.0 colorful-0.5.7 deprecation-2.1.0 distlib-0.3.9 fastapi-0.109.2 filelock-3.18.0 frozenlist-1.7.0 grpcio-1.73.1 h11-0.16.0 httpcore-1.0.9 httpx-0.26.0 kfp-2.5.0 kfp-pipeline-spec-0.2.2 kfp-server-api-2.0.5 kserve-0.13.1 kubernetes-26.1.0 multidict-6.6.3 opencensus-0.11.4 opencensus-context-0.1.3 orjson-3.10.18 prometheus-client-0.20.0 propcache-0.3.2 protobuf-3.20.3 psutil-5.9.8 py-spy-0.4.0 ray-2.10.0 smart-open-7.3.0.post1 starlette-0.36.3 timing-asgi-0.3.1 uvicorn-0.21.1 virtualenv-20.31.2 wrapt-1.17.2 yarl-1.20.1

# %%
import kfp
import mlflow
import os
import requests

from kfp.dsl import Input, Model, component
from kfp.dsl import InputPath, OutputPath, pipeline, component
from kserve import KServeClient
from mlflow.tracking import MlflowClient
from tenacity import retry, stop_after_attempt, wait_exponential
# Out:
# /opt/conda/lib/python3.11/site-packages/mlflow/utils/requirements_utils.py:20: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources  # noqa: TID251

# %% [markdown]
# # Dataset processing

# %%
@component(
    base_image="python:3.11",
    packages_to_install=["requests==2.32.3", "pandas==2.2.2"]
)
def download_dataset(url: str, dataset_path: OutputPath('Dataset')) -> None:
    import requests
    import pandas as pd

    response = requests.get(url)
    response.raise_for_status()

    from io import StringIO
    dataset = pd.read_csv(StringIO(response.text), header=0, sep=";")

    dataset.to_csv(dataset_path, index=False)

# %%
@component(
    base_image="python:3.11",
    packages_to_install=["pandas==2.2.2", "pyarrow==15.0.2"]
)
def preprocess_dataset(dataset: InputPath('Dataset'), output_file: OutputPath('Dataset')) -> None:
    import pandas as pd
    
    df = pd.read_csv(dataset, header=0)
    df.columns = [c.lower().replace(" ", "_") for c in df.columns]
    df.to_parquet(output_file)

# %% [markdown]
# # Model training

# %%
@component(
    base_image="python:3.11",
    packages_to_install=["pandas==2.2.2", "scikit-learn==1.5.1", "mlflow==2.15.1", "pyarrow==15.0.2", "boto3==1.34.162"]
)
def train_model(dataset: InputPath('Dataset'), run_name: str, model_name: str) -> str:
    import os
    import mlflow
    import pandas as pd
    from sklearn.linear_model import ElasticNet
    from sklearn.model_selection import train_test_split

    df = pd.read_parquet(dataset)
    
    target_column = "quality"

    train_x, test_x, train_y, test_y = train_test_split(
        df.drop(columns=[target_column]),
        df[target_column], test_size=0.25,
        random_state=42, stratify=df[target_column]
    )

    mlflow.sklearn.autolog()
    
    with mlflow.start_run(run_name=run_name) as run:
        mlflow.set_tag("author", "kf-testing")
        lr = ElasticNet(alpha=0.5, l1_ratio=0.5, random_state=42)
        lr.fit(train_x, train_y)
        mlflow.sklearn.log_model(lr, "model", registered_model_name=model_name)
        
        model_uri = f"{run.info.artifact_uri}/model"
        print(model_uri)
        return model_uri

# %% [markdown]
# # Model serving

# %%
@component(
    base_image="python:3.11",
    packages_to_install=["kserve==0.13.1", "kubernetes==26.1.0", "tenacity==9.0.0"]
)
def deploy_model_with_kserve(model_uri: str, isvc_name: str) -> str:
    from kubernetes.client import V1ObjectMeta
    from kserve import (
        constants,
        KServeClient,
        V1beta1InferenceService,
        V1beta1InferenceServiceSpec,
        V1beta1PredictorSpec,
        V1beta1SKLearnSpec,
    )
    from tenacity import retry, wait_exponential, stop_after_attempt

    isvc = V1beta1InferenceService(
        api_version=constants.KSERVE_V1BETA1,
        kind=constants.KSERVE_KIND,
        metadata=V1ObjectMeta(
            name=isvc_name,
            annotations={"sidecar.istio.io/inject": "false"},
        ),
        spec=V1beta1InferenceServiceSpec(
            predictor=V1beta1PredictorSpec(
                service_account_name="kserve-controller-s3",
                sklearn=V1beta1SKLearnSpec(
                    storage_uri=model_uri
                )
            )
        )
    )
    
    client = KServeClient()
    client.create(isvc)

    @retry(
        wait=wait_exponential(multiplier=2, min=1, max=10),
        stop=stop_after_attempt(30),
        reraise=True,
    )
    def assert_isvc_created(client, isvc_name):
        assert client.is_isvc_ready(isvc_name), f"Failed to create Inference Service {isvc_name}."

    assert_isvc_created(client, isvc_name)
    isvc_resp = client.get(isvc_name)
    isvc_url = isvc_resp['status']['address']['url']
    print("Inference URL:", isvc_url)
    
    return isvc_url

# %% [markdown]
# # Define pipeline & artifact

# %%
ISVC_NAME = "wine-regressor4"
MLFLOW_RUN_NAME = "elastic_net_models"
MLFLOW_MODEL_NAME = "wine-elasticnet"

mlflow_tracking_uri = os.getenv('MLFLOW_TRACKING_URI')
mlflow_s3_endpoint_url = os.getenv('MLFLOW_S3_ENDPOINT_URL')
aws_access_key_id = os.getenv('AWS_ACCESS_KEY_ID')
aws_secret_access_key = os.getenv('AWS_SECRET_ACCESS_KEY')

@pipeline(name='download-preprocess-train-deploy-pipeline')
def download_preprocess_train_deploy_pipeline(url: str):
    download_task = download_dataset(url=url)
    
    preprocess_task = preprocess_dataset(
        dataset=download_task.outputs['dataset_path']
    )
    
    train_task = train_model(
        dataset=preprocess_task.outputs['output_file'], run_name=MLFLOW_RUN_NAME, model_name=MLFLOW_MODEL_NAME
    ).set_env_variable(name='MLFLOW_TRACKING_URI', value=mlflow_tracking_uri)\
     .set_env_variable(name='MLFLOW_S3_ENDPOINT_URL', value=mlflow_s3_endpoint_url)\
     .set_env_variable(name='AWS_ACCESS_KEY_ID', value=aws_access_key_id)\
     .set_env_variable(name='AWS_SECRET_ACCESS_KEY', value=aws_secret_access_key)
    
    deploy_task = deploy_model_with_kserve(
        model_uri=train_task.output, isvc_name=ISVC_NAME
    ).set_env_variable(name='AWS_SECRET_ACCESS_KEY', value=aws_secret_access_key)

# %%
client = kfp.Client()

url = 'https://raw.githubusercontent.com/canonical/kubeflow-examples/main/e2e-wine-kfp-mlflow/winequality-red.csv'

kfp.compiler.Compiler().compile(download_preprocess_train_deploy_pipeline, 'download_preprocess_train_deploy_pipeline.yaml')

run = client.create_run_from_pipeline_func(download_preprocess_train_deploy_pipeline, arguments={'url': url}, enable_caching=False)
# Out:
# /opt/conda/lib/python3.11/site-packages/kfp/client/client.py:159: FutureWarning: This client only works with Kubeflow Pipeline v2.0.0-beta.2 and later versions.
#   warnings.warn(
# <a href="/pipeline/#/experiments/details/b6a6b792-d03e-4041-8368-85faf93a55f2" target="_blank" >Experiment details</a>.
# <a href="/pipeline/#/runs/details/f968c133-8a9e-4b5b-bde5-94c7b19dede8" target="_blank" >Run details</a>.

# %%
# @retry(
#     wait=wait_exponential(multiplier=2, min=1, max=10),
#     stop=stop_after_attempt(90),
#     reraise=True,
# )
# def assert_kfp_run_succeeded(client, run_id):
#     run = client.get_run(run_id=run_id)
#     state = run.state
#     assert state == "SUCCEEDED", f"KFP run is in {state} state."

# assert_kfp_run_succeeded(client, run.run_id)

# %% [markdown]
# # Test serving

# %%
kserve_client = KServeClient()

isvc_resp = kserve_client.get(ISVC_NAME)
inference_service_url = isvc_resp['status']['address']['url']
print("Inference URL:", inference_service_url)

input_data = {
    "instances": [
        [7.4, 0.7, 0.0, 1.9, 0.076, 11.0, 34.0, 0.9978, 3.51, 0.56, 9.4],
        [7.8, 0.88, 0.0, 2.6, 0.098, 25.0, 67.0, 0.9968, 3.2, 0.68, 9.8]
    ]
}

response = requests.post(f"{inference_service_url}/v1/models/{ISVC_NAME}:predict", json=input_data)
print(response.text)
# Out:
# Inference URL: http://wine-regressor4.admin.svc.cluster.local
# {"predictions":[5.575510497546586,5.527143590500911]}

# %% [markdown]
# # Remove

# %%
kserve_client.delete(ISVC_NAME)

@retry(
    wait=wait_exponential(multiplier=2, min=1, max=10),
    stop=stop_after_attempt(30),
    reraise=True,
)
def assert_isvc_deleted(kserve_client, isvc_name):
    try:
        isvc = kserve_client.get(isvc_name)
        assert not isvc, f"Failed to delete Inference Service {isvc_name}!"
    except RuntimeError as err:
        assert "Not Found" in str(err), f"Caught unexpected exception: {err}"

assert_isvc_deleted(kserve_client, ISVC_NAME)

client = MlflowClient()
client.delete_registered_model(name=MLFLOW_MODEL_NAME)
